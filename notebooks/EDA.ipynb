# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#Import data file.

df = pd.read_csv(r"C:\Users\hp\My Project\Project Cat Breeds v2 (Classification) (10 class)\cat_breeds_clean.csv")

df
# Out:
#                  Breeds    Origin  Weight  length Fur_length Fur_type  \
# 0               Siamese  Thailand     5.4      39      short     soft
# 1               Siamese  Thailand     3.8      31      short     soft
# 2               Siamese  Thailand     4.9      37      short     soft
# 3               Siamese  Thailand     5.4      31      short     soft
# 4               Siamese  Thailand     3.0      37      short     soft
# ...                 ...       ...     ...     ...        ...      ...
# 1409  British Shorthair        UK     7.2      38      short    heavy
# 1410  British Shorthair        UK     5.7      30      short    heavy
# 1411  British Shorthair        UK     6.3      37      short    heavy
# 1412  British Shorthair        UK     4.7      34      short    heavy
# 1413  British Shorthair        UK     4.9      30      short    heavy
#
#      Fur_color Eye_color  Age  Sleep_hours
# 0        white      blue   13           15
# ...

# %%
#Make sure the names are clear and understandable in each column.

print(df.columns)
# Out:
# Index(['Breeds', 'Origin', 'Weight', 'length', 'Fur_length', 'Fur_type',
#        'Fur_color', 'Eye_color', 'Age', 'Sleep_hours'],
#       dtype='object')

# %%
#Data summary

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1414 entries, 0 to 1413
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Breeds       1414 non-null   object
#  1   Origin       1414 non-null   object
#  2   Weight       1414 non-null   float64
#  3   length       1414 non-null   int64
#  4   Fur_length   1414 non-null   object
#  5   Fur_type     1414 non-null   object
#  6   Fur_color    1414 non-null   object
#  7   Eye_color    1414 non-null   object
#  8   Age          1414 non-null   int64
#  9   Sleep_hours  1414 non-null   int64
# dtypes: float64(1), int64(3), object(6)
# memory usage: 110.6+ KB

# %%
#Ensure that each column has a logical data type and understandable values.

print(df.head())
# Out:
#     Breeds    Origin  Weight  length Fur_length Fur_type Fur_color Eye_color  \
# 0  Siamese  Thailand     5.4      39      short     soft     white      blue
# 1  Siamese  Thailand     3.8      31      short     soft    creamy      blue
# 2  Siamese  Thailand     4.9      37      short     soft     white      blue
# 3  Siamese  Thailand     5.4      31      short     soft    creamy      blue
# 4  Siamese  Thailand     3.0      37      short     soft     white      blue
#
#    Age  Sleep_hours
# 0   13           15
# 1   14           12
# 2   14           16
# 3   12           15
# 4   12           12

# %%
#Analyze unique values for each column.

for col in df.columns:
    print(f"{col} - number of nunique value :", df[col].nunique())
# Out:
# Breeds - number of nunique value : 10
# Origin - number of nunique value : 9
# Weight - number of nunique value : 85
# length - number of nunique value : 76
# Fur_length - number of nunique value : 4
# Fur_type - number of nunique value : 4
# Fur_color - number of nunique value : 14
# Eye_color - number of nunique value : 8
# Age - number of nunique value : 12
# Sleep_hours - number of nunique value : 7

# %%
#Are there any columns that contain illogical values (such as negative numbers for age or weight).

print(df[df['Weight'] < 0])
print(df[df['length'] < 0])
print(df[df['Age'] < 0])
# Out:
# Empty DataFrame
# Columns: [Breeds, Origin, Weight, length, Fur_length, Fur_type, Fur_color, Eye_color, Age, Sleep_hours]
# Index: []
# Empty DataFrame
# Columns: [Breeds, Origin, Weight, length, Fur_length, Fur_type, Fur_color, Eye_color, Age, Sleep_hours]
# Index: []
# Empty DataFrame
# Columns: [Breeds, Origin, Weight, length, Fur_length, Fur_type, Fur_color, Eye_color, Age, Sleep_hours]
# Index: []

# %%
#Check balanced distribution (Percentages for each category).

print(round(df['Breeds'].value_counts(normalize=True) * 100, 1))
# Out:
# Breeds
# Persian                 14.1
# Norwegian Forest Cat    14.1
# Abyssinian              10.6
# Egyption Mau            10.6
# Turkish Angora          10.6
# Maine Coon              10.6
# British Shorthair        8.1
# Manx                     7.1
# Japanese Bobtail         7.1
# Siamese                  7.0
# Name: proportion, dtype: float64

# %%
#A graph showing the distribution.

df['Breeds'].value_counts().plot(kind='bar')
plt.title('Distribution of Cat Breeds')
plt.xlabel('Breed')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %%
#Age and weight distribution plot for each breed.

plt.figure(figsize=(10,6))
sns.boxplot(data=df, x='Breeds', y='Age')
plt.xticks(rotation=45)
plt.title('Age Distribution by Cat Breed')
plt.tight_layout()
plt.show()

plt.figure(figsize=(10,6))
sns.boxplot(data=df, x='Breeds', y='Weight')
plt.xticks(rotation=45)
plt.title('Weight Distribution by Cat Breed')
plt.tight_layout()
plt.show()

plt.figure(figsize=(10,6))
sns.boxplot(data=df, x='Breeds', y='length')
plt.xticks(rotation=45)
plt.title('Length Distribution by Cat Breed')
plt.tight_layout()
plt.show()

# %%
#The relationship between weight, length, age and sleep_hours for each breed.

sns.pairplot(df, hue='Breeds', vars=['Weight', 'length', 'Age', 'Sleep_hours'])
plt.show()
